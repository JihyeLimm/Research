# %% [markdown]
# <a href="https://colab.research.google.com/github/JihyeLimm/Research/blob/main/noname/candidate_scibert_acc_0.5614.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/gdrive', force_remount = True)
os.chdir("/gdrive/MyDrive/exercise/230905")
os.getcwd()
# Out:
# Mounted at /gdrive
# '/gdrive/MyDrive/exercise/230905'

# %%
# %%capture
# !pip install transformers
# !pip install python-box
from box import Box

# %%
import os
import pandas as pd
import numpy as np
import re
import random
from datetime import datetime

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import sequence

from gensim.models import doc2vec
from gensim.models.doc2vec import TaggedDocument
from tqdm import tqdm

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

from transformers import *     #BertTokenizer

import warnings
warnings.filterwarnings(action = 'ignore')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation_tf_utils.py:24: FutureWarning: Importing `TFGenerationMixin` from `src/transformers/generation_tf_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import TFGenerationMixin` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation_flax_utils.py:24: FutureWarning: Importing `FlaxGenerationMixin` from `src/transformers/generation_flax_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import FlaxGenerationMixin` instead.
#   warnings.warn(
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
def analyze_dataframe(df, item_col_name, user_col_name=None, feedback_col_name=None):
    # 총 데이터 개수
    print(f'총 데이터 raw 수: {len(df)}')

    # item 수가 많은지 user 수가 많은지
    num_items = df[item_col_name].nunique()
    print(f'고유 Item 개수: {num_items}')

    # user_col_name이 제공된 경우에만 고유 user 수를 출력
    if user_col_name:
        num_users = df[user_col_name].nunique()
        print(f'고유 user 수: {num_users}')

    # user feedback 컬럼명을 받으면, 해당 값의 분포와 long tail인지, scaling이 필요한지
    if feedback_col_name:
        feedback_data = df[feedback_col_name]
        plt.figure(figsize=(10, 4))
        sns.histplot(feedback_data, kde=True)
        plt.xlabel(feedback_col_name)
        plt.ylabel('빈도')
        plt.title(f'유저 피드백 변수 {feedback_col_name}의 분포')
        plt.show()

        # Feedback scaling suggestion
        if feedback_data.skew() > 1:
            print(f"해당 {feedback_col_name} 컬럼에 롱테일 분포가 있습니다. 예를 들어 로그 변환을 사용하여 확장하는 것이 좋습니다.")
    else:
        print('유저 피드백 변수는 없습니다.')

    # 정규화가 필요한 컬럼이 있는지(있다면 분포가 어떻게 되는지)
    numeric_columns = df.select_dtypes(include=[np.number]).columns
    for col in numeric_columns:
        if df[col].std()>df[col].mean()*0.3:
          print(f"해당 연속형 변수 '{col}' 컬럼: (표준 편차값: {df[col].std()}, 평균: {df[col].mean()}) [●정규화 유의] std>평균*30% 이상 ")
        else:
          print(f"해당 연속형 변수 '{col}' 컬럼 : (표준 편차값: {df[col].std()}, 평균: {df[col].mean()})")
        # if df[col].std() > 1:
        #     print(f"해당 연속형 변수 '{col}' 컬럼은 표준 편차가 1보다 훨씬 크기 때문에 정규화가 필요할 수 있습니다 (표준 편차값: {df[col].std()})")
        # elif df[col].std() < 0.5:
        #     print(f"해당 연속형 변수 '{col}' 컬럼은 표준 편차가 0.5보다 작기 때문에 정규화가 필요할 수 있습니다 (표준 편차값: {df[col].std()})")

    # 컬럼들 중 범주형 변수와 연속형 변수의 개수와 각각의 비율
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns
    num_categorical = len(categorical_columns)
    num_continuous = len(numeric_columns)
    total_columns = num_categorical + num_continuous

    print(f"범주형 변수 개수: {num_categorical} ({num_categorical / total_columns:.2%})")
    print(f"연속형 변수 개수: {num_continuous} ({num_continuous / total_columns:.2%})")
    print(f"총 변수 개수: {total_columns}")

    # 시계열 데이터 컬럼이 있는지 유무
    datetime_columns = df.select_dtypes(include=['datetime', 'datetime64']).columns.tolist()

    # 문자열 형태로 저장된 시계열 데이터를 찾는 부분 추가
    for col in df.select_dtypes(include=['object']).columns:
        try:
            pd.to_datetime(df[col], errors='raise')
            datetime_columns.append(col)
        except:
            pass  # 이 경우, 해당 컬럼은 시계열 데이터가 아님

    if not datetime_columns:
        print('시계열 데이터 없음')
    else:
        print(f'시계열 데이터 컬럼: {datetime_columns}')


    # 컬럼 중에 NaN 값이 있으면 해당 컬럼의 NaN 값 비율을 출력
    for col in df.columns:
        nan_ratio = df[col].isna().sum() / len(df)
        if nan_ratio > 0:
            print(f"'{col}' 컬럼의  NaN 값 비율: {nan_ratio:.2%}")

    # 범주형 변수의 값들과 값들의 비율을 dictionary 형태로 출력
    for col in categorical_columns:
        value_counts = df[col].value_counts(normalize=True, dropna=False)

        # Sorting by value in descending order and limiting to top 30
        sorted_value_counts = sorted(value_counts.items(), key=lambda x: x[1], reverse=True)[:30]
        value_ratios = {value: f"{count * 100:.2f}%" for value, count in sorted_value_counts}
        print(f"범주형 변수 '{col}' 컬럼 값 비율 (상위 30개): {value_ratios}")


      # 롱테일 분포 확인 (user_col_name이 제공된 경우에만 실행)
    if feedback_col_name and user_col_name:
        # 사용자별 평점 횟수 확인
        user_rating_count = df[user_col_name].value_counts()
        plt.figure(figsize=(10, 4))
        user_rating_count.plot(kind='hist', bins=30)
        plt.xlabel('1유저당 매긴 평점 개수')
        plt.ylabel('해당 사용자 수')
        plt.title('1유저당 매긴 평점 개수 분포')
        plt.show()

        # 아이템별 평점 횟수 확인
        item_rating_count = df[item_col_name].value_counts()
        plt.figure(figsize=(10, 4))
        item_rating_count.plot(kind='hist', bins=30)
        plt.xlabel('1아이템당 받은 평점 개수')
        plt.ylabel('해당 아이템 수')
        plt.title('1아이템당 받은 평점 개수 분포')
        plt.show()

# %% [markdown]
# Data load

# %%
path = './data/'
base_df = pd.read_csv(os.path.join(path, 'author_paper_43213_230907.csv'), encoding='utf-8',error_bad_lines=False) #error_bad_lines 무시
#base_df = bbase_df.drop(columns=["old_paper_id", "subject", "topic", "funding"])
print(base_df.shape)
base_df.tail(3)
# Out:
# (43213, 10)
#        old_paper_id  paper_id    author_id  author_type  \
# 43210         16314     15432  56022661100            3
# 43211         16314     15432  56589320900            2
# 43212         16314     15432  57188726348            1
#
#                                                    title  year        source  \
# 43210  The role of complexity in the Valley of Death ...  2022  Technovation
# 43211  The role of complexity in the Valley of Death ...  2022  Technovation
# 43212  The role of complexity in the Valley of Death ...  2022  Technovation
#
#        citation                                           abstract  \
# 43210         7  Firms invest much of their capital into basic ...
# 43211         7  Firms invest much of their capital into basic ...
# 43212         7  Firms invest much of their capital into basic ...
#
#                                                 keywords
# 43210  Motivation-opportunity-ability framework; Orga...
# 43211  Motivation-opportunity-ability framework; Orga...
# 43212  Motivation-opportunity-ability framework; Orga...

# %%
# NaN 값을 제거하기 위해 필요한 경우 아래 코드를 추가로 실행
base_df = base_df.dropna()

# 범주형 피처 리스트
categorical_features = ['author_type', 'source', 'keywords']

# author_type, source 범주형으로 바꾸기
base_df['author_type'] = base_df['author_type'].astype(str)
base_df['source'] = base_df['source'].astype(str)

# 텍스트 전처리
def preprocess_text(text):
    # 소문자로 변환
    text = text.lower()
    # 특수 문자 제거
    text = re.sub(r'\W', ' ', text)
    # 한 글자짜리 단어 제거
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
    # 여러 개의 공백을 하나로 줄임
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    # 'b'로 시작하는 문자열 제거
    #text = re.sub(r'^b\s+', '', text)
    return text

def preprocess_keyword(text):
    # 소문자로 변환
    text = text.lower()
    # 특수 문자 제거
    # text = re.sub(r'\W', ' ', text)
    # 한 글자짜리 단어 제거
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
    # 여러 개의 공백을 하나로 줄임
    # text = re.sub(r'\s+', ' ', text, flags=re.I)
    # 'b'로 시작하는 문자열 제거
    #text = re.sub(r'^b\s+', '', text)
    return text


#title & abstract는 텍스트 전처리
base_df['title'] = base_df['title'].apply(preprocess_text)
base_df['abstract'] = base_df['abstract'].apply(preprocess_text)
base_df['keywords_'] = base_df['keywords'].apply(preprocess_text)

#keywords는 소문자 전처리
base_df['keywords'] = base_df['keywords'].apply(preprocess_keyword)


# 중복 논문 삭제
base_df = base_df.sort_values(by='citation', ascending=False).drop_duplicates(subset=['title', 'author_id'], keep='first')

  # 삭제된 행 찾기
  #deleted_rows = base_df[~base_df['paper_id'].isin(filtered_df['paper_id'])]

# 인덱스를 리셋
base_df = base_df.reset_index(drop=True)

#저자-논문 관계를 나타내는 column생성
base_df['write'] = 1

base_df = base_df.sort_values(by="paper_id", ascending=True)
base_df = base_df.reset_index(drop=True)
print(base_df.shape)
base_df.sample(3)
# Out:
# (43212, 12)
#        old_paper_id  paper_id    author_id author_type  \
# 13933         13450      5895  36801694800           1
# 21552          2485      8616  25926392700           2
# 34308         11266     12727   6506322858           1
#
#                                                    title  year  \
# 13933  an integrated two stage diffusion of innovatio...  2014
# 21552  a glance at research driven university technol...  2018
# 34308  impact of covid 19 on the travel and tourism i...  2021
#
#                                                source  citation  \
# 13933     Technological Forecasting and Social Change         7
# 21552  International Journal of Technology Management         1
# 34308     Technological Forecasting and Social Change       269
#
#                                                 abstract  \
# 13933  with the aid of the internet both firms and cu...
# 21552  technology transfer offices ttos in research d...
# 34308  our paper is among the first to measure the po...
#
#                                                 keywords  \
# 13933  bayesian learning; innovation adoption modelin...
# 21552  business incubation; research-driven universit...
# 34308  covid-19; financial cycles; pandemic crises; p...
#
#                                                keywords_  write
# 13933  bayesian learning innovation adoption modeling...      1
# 21552  business incubation research driven university...      1
# 34308  covid 19 financial cycles pandemic crises pane...      1

# %%
analyze_dataframe(base_df,item_col_name='paper_id',user_col_name='author_id')
# Out:
# 총 데이터 raw 수: 43212
# 고유 Item 개수: 15432
# 고유 user 수: 25959
# 유저 피드백 변수는 없습니다.
# 해당 연속형 변수 'old_paper_id' 컬럼: (표준 편차값: 5165.035535015935, 평균: 8959.296954549662) [●정규화 유의] std>평균*30% 이상
# 해당 연속형 변수 'paper_id' 컬럼: (표준 편차값: 4388.746787239068, 평균: 8342.681847634916) [●정규화 유의] std>평균*30% 이상
# 해당 연속형 변수 'author_id' 컬럼: (표준 편차값: 21298857046.908516, 평균: 36058020660.57639) [●정규화 유의] std>평균*30% 이상
# 해당 연속형 변수 'year' 컬럼 : (표준 편차값: 5.464729492589677, 평균: 2016.1370221234843)
# 해당 연속형 변수 'citation' 컬럼: (표준 편차값: 84.42562926506565, 평균: 37.994376562066094) [●정규화 유의] std>평균*30% 이상
# 해당 연속형 변수 'write' 컬럼 : (표준 편차값: 0.0, 평균: 1.0)
# 범주형 변수 개수: 6 (50.00%)
# 연속형 변수 개수: 6 (50.00%)
# 총 변수 개수: 12
# 시계열 데이터 없음
# 범주형 변수 'author_type' 컬럼 값 비율 (상위 30개): {'1': '35.71%', '2': '30.38%', '3': '19.43%', '4': '8.83%', '5': '3.15%', '6': '1.12%', '7': '0.44%', '8': '0.25%', '9': '0.15%', '10': '0.10%', '11': '0.08%', '12': '0.05%', '13': '0.04%', '14': '0.03%', '15': '0.03%', '16': '0.03%', '19': '0.02%', '18': '0.02%', '17': '0.02%', '20': '0.02%', '22': '0.01%', '21': '0.01%', '24': '0.01%', '23': '0.01%', '25': '0.01%', '26': '0.01%', '31': '0.00%', '27': '0.00%', '29': '0.00%', '28': '0.00%'}
# 범주형 변수 'title' 컬럼 값 비율 (상위 30개): {'a short note on integrated assessment modeling approaches rejoinder to the review of making or breaking climate targets the ampere study on staged accession scenarios for climate policy ': '0.07%', 'examining open innovation in science ois what open innovation can and cannot offer the science of science': '0.07%', 'the european university landscape micro characterization based on evidence from the aquameth project': '0.06%', 'making or breaking climate targets the ampere study on staged accession scenarios for climate policy': '0.06%', 'locked into copenhagen pledges implications of short term emission targets for the cost and feasibility of long term climate goals': '0.06%', 'technology foresight for medical device development through hybrid simulation the prohta project': '0.05%', 'inventors and invention processes in europe results from the patval eu survey': '0.05%', 'a review of literature on evaluating the scientific social and political impact of social sciences and humanities research': '0.04%', 'technology futures analysis toward integration of the field and new methods': '0.04%', 'comprehensiveness of national bibliographic databases for social sciences and humanities findings from european survey': '0.04%', 'deploying artificial intelligence for climate change adaptation': '0.04%', 'academic engagement and commercialisation review of the literature on university industry relations': '0.04%', 'diagnostic indicators for integrated assessment models of climate policy': '0.03%', 'an agent based modeling and virtual reality application using distributed simulation case of covid 19 intensive care unit': '0.03%', 'reporting errors and biases in published empirical findings evidence from innovation research': '0.03%', 'co2 emission mitigation and fossil fuel markets dynamic and international aspects of climate policies': '0.03%', 'serious games for energy social science research': '0.03%', 'do synthesis centers synthesize semantic analysis of topical diversity in research': '0.03%', 'an integrated scenario analysis for the metal coating sector in europe': '0.03%', 'long term global water projections using six socioeconomic scenarios in an integrated assessment modeling framework': '0.03%', 'barriers to open learning in public administrations comparative case study of the european countries luxembourg germany montenegro and ireland': '0.03%', 'impact oriented monitoring new methodology for monitoring and evaluation of international public health research projects': '0.03%', 'influencing factors of patient satisfaction in teleconsultation cross sectional study': '0.03%', 'a neuro advertising property video recommendation system': '0.03%', 'citizen science and sustainability transitions': '0.03%', 'unlocking value for circular economy through 3d printing research agenda': '0.03%', ' peace engineering in practice case study at the university of new mexico ': '0.03%', 'social network analysis of scientist practitioner research initiative established to facilitate science dissemination and implementation within states and communities': '0.03%', 'the exploratory analysis of trade offs in strategic planning lessons from regional infrastructure foresight': '0.03%', 'transformative social innovation and dis empowerment': '0.03%'}
# 범주형 변수 'source' 컬럼 값 비율 (상위 30개): {'Technological Forecasting and Social Change': '32.95%', 'Research Policy': '14.68%', 'IEEE Transactions on Engineering Management': '13.65%', 'Technology Analysis and Strategic Management': '9.08%', 'Technovation': '7.92%', 'International Journal of Technology Management': '6.05%', 'Journal of Technology Transfer': '5.74%', 'Journal of Engineering and Technology Management - JET-M': '2.57%', 'Research Evaluation': '2.21%', 'Research Technology Management': '2.17%', 'Innovation: Management, Policy and Practice': '1.67%', 'Innovation: Organization and Management': '0.78%', 'Journal of Product Innovation Management': '0.53%', 'R and D Management': '0.01%'}
# 범주형 변수 'abstract' 컬럼 값 비율 (상위 30개): {'we provide rejoinder to review rosen 2015 of our original article making or breaking climate targets the ampere study on staged accession scenarios for climate policy kriegler et al 2015a we have substantial disagreement with the content of the review and feel that it is plagued by number of misconceptions about the nature of the ampere study and the integrated assessment modeling approach employed by it we therefore see this rejoinder as an opportunity to clarify these misconceptions and advance the debate by providing clearer understanding of the strengths weaknesses and ultimately the value of integrated assessment 2015 elsevier inc ': '0.07%', 'scholars across disciplines increasingly hear calls for more open and collaborative approaches to scientific research the concept of open innovation in science ois provides framework that integrates dispersed research efforts aiming to understand the antecedents contingencies and consequences of applying open and collaborative research practices while the ois framework has already been taken up by science of science scholars its conceptual underpinnings require further specification in this essay we critically examine the ois concept and bring to light two key aspects 1 how ois builds upon open innovation oi research by adopting its attention to boundary crossing knowledge flows and by adapting other concepts developed and researched in oi to the science context as exemplified by two ois cases in the area of research funding 2 how ois conceptualises knowledge flows across boundaries while oi typically focuses on well defined organisational boundaries we argue that blurry and even invisible boundaries between communities of practice may more strongly constrain flows of knowledge related to openness and collaboration in science given the uptake of this concept this essay brings needed clarity to the meaning of ois which has no particular normative orientation towards close coupling between science and industry we end by outlining the essay contributions to oi and the science of science as well as to science practitioners 2021 the author published by informa uk limited trading as taylor francis group ': '0.07%', 'this paper provides new and systematic characterization of 488 universities from 11 european countries finland france germany hungary italy netherlands norway portugal spain switzerland and uk using micro indicators built on the integrated aquameth database we characterize the european university landscape according to the following dimensions history foundation of university dynamics of growth specialization pattern subject mix funding composition offer profile and productivity 2010 elsevier v all rights reserved ': '0.06%', 'this paper provides an overview of the ampere modeling comparison project with focus on the implications of near term policies for the costs and attainability of long term climate objectives nine modeling teams participated in the project to explore the consequences of global emissions following the proposed policy stringency of the national pledges from the copenhagen accord and cancún agreements to 2030 specific features compared to earlier assessments are the explicit consideration of near term 2030 emission targets as well as the systematic sensitivity analysis for the availability and potential of mitigation technologies our estimates show that 2030 mitigation effort comparable to the pledges would result in further lock in of the energy system into fossil fuels and thus impede the required energy transformation to reach low greenhouse gas stabilization levels 450ppm co2e major implications include significant increases in mitigation costs increased risk that low stabilization targets become unattainable and reduced chances of staying below the proposed temperature change target of 2 in case of overshoot with respect to technologies we find that following the pledge pathways to 2030 would narrow policy choices a ...
# 범주형 변수 'keywords' 컬럼 값 비율 (상위 30개): {'integrated assessment modeling; mitigation costs; model comparison; model documentation; peer review': '0.07%', 'boundaries; boundary crossing; knowledge flows; open innovation; open innovation in science; open science; science of science; scientific research': '0.07%', 'differentiation; growth; productivity; size; specialization; universities': '0.06%', 'carbon leakage; climate change economics; climate change mitigation; european union; integrated assessment models; regional climate policies': '0.06%', 'ampere; climate policy; copenhagen pledges; greenhouse gas emissions; mitigation': '0.06%', 'early technology assessment; foresight; health care; medical device; simulation; stroke': '0.05%', 'academic consulting; academic entrepreneurship; collaborative research; commercialisation; technology transfer; university-industry relations': '0.05%', 'collaboration; invention process; inventor; licensing; patent': '0.05%', 'forecasting; research and development; technology futures analysis': '0.04%', 'evaluation; humanities; impact assessment; social sciences': '0.04%', 'database; europe; research information; social sciences and humanities; ssh': '0.04%', 'artificial intelligence; climate change adaptation; digital technologies': '0.04%', 'climate change economics; climate policy; energy system models; integrated assessment models; model diagnostics': '0.03%', 'agent-based modeling (abm); cloud computing; computational modeling; covid-19; covid-19; data models; discrete event simulation (des); distributed simulation (ds); healthcare systems; high-level architecture (hla); hospitals; hybrid simulation; intensive care unit (icu); interoperability; interoperability; pandemics; solid modeling; virtual reality (vr)': '0.03%', 'complex systems; economic complexity; geography; innovation; policy': '0.03%', 'caliper test; innovation; p-hacking; publication bias; reporting bias; reporting error': '0.03%', 'carbon capture and storage (ccs); low carbon technology; socio-technical systems; technology assessment; uncertainties': '0.03%', 'carbon leakage; climate change mitigation policies; copenhagen accord; fossil fuel markets; inter-fuel substitution': '0.03%', 'domestic energy demand; evaluation framework; feedback mechanisms; serious games': '0.03%', 'creativity; diversity; innovation; interdisciplinary research; scientific collaboration; semantic analysis; synthesis': '0.03%', 'influencing factors; medical expenses; patient cognition; patient satisfaction; perceived quality; teleconsultation': '0.03%', 'gcam; integrated assessment; socioeconomic scenarios; water consumption; water scarcity; water withdrawals': '0.03%', 'impact identification and assessment; international public health; monitoring and evaluation; research projects': '0.03%', 'comparative study; e-learning; oer; public administrations': '0.03%', 'metal coating; scenario analysis; value chain; voc (volatile organic compounds)': '0.03%', 'affective computing; knowledge-based real-world applications; mcda; methods; neuro decision matrix; property': '0.03%', 'bibliometrics; china; clustering; computational linguistics; india; metrics; research evaluation; science and technology; technology assessment; text mining': '0.03%', 'crowdsourcing; land cover; land use; validation; volunteered geographic information': '0.03%', '3d printing; additive manufacturing; circular economy; research agenda; sustainability': '0.03%', 'dissemination and implementation; public health; science-to-practice; social network analysis; tobacco control': '0.03%'}
# 범주형 변수 'keywords_' 컬럼 값 비율 (상위 30개): {'integrated assessment modeling mitigation costs model comparison model documentation peer review': '0.07%', 'boundaries boundary crossing knowledge flows open innovation open innovation in science open science science of science scientific research': '0.07%', 'differentiation growth productivity size specialization universities': '0.06%', 'carbon leakage climate change economics climate change mitigation european union integrated assessment models regional climate policies': '0.06%', 'ampere climate policy copenhagen pledges greenhouse gas emissions mitigation': '0.06%', 'early technology assessment foresight health care medical device simulation stroke': '0.05%', 'academic consulting academic entrepreneurship collaborative research commercialisation technology transfer university industry relations': '0.05%', 'collaboration invention process inventor licensing patent': '0.05%', 'database europe research information social sciences and humanities ssh': '0.04%', 'evaluation humanities impact assessment social sciences': '0.04%', 'forecasting research and development technology futures analysis': '0.04%', 'artificial intelligence climate change adaptation digital technologies': '0.04%', 'agent based modeling abm cloud computing computational modeling covid 19 covid 19 data models discrete event simulation des distributed simulation ds healthcare systems high level architecture hla hospitals hybrid simulation intensive care unit icu interoperability interoperability pandemics solid modeling virtual reality vr ': '0.03%', 'climate change economics climate policy energy system models integrated assessment models model diagnostics': '0.03%', 'complex systems economic complexity geography innovation policy': '0.03%', 'caliper test innovation hacking publication bias reporting bias reporting error': '0.03%', 'domestic energy demand evaluation framework feedback mechanisms serious games': '0.03%', 'carbon capture and storage ccs low carbon technology socio technical systems technology assessment uncertainties': '0.03%', 'carbon leakage climate change mitigation policies copenhagen accord fossil fuel markets inter fuel substitution': '0.03%', 'gcam integrated assessment socioeconomic scenarios water consumption water scarcity water withdrawals': '0.03%', 'influencing factors medical expenses patient cognition patient satisfaction perceived quality teleconsultation': '0.03%', 'metal coating scenario analysis value chain voc volatile organic compounds ': '0.03%', 'comparative study learning oer public administrations': '0.03%', 'impact identification and assessment international public health monitoring and evaluation research projects': '0.03%', 'creativity diversity innovation interdisciplinary research scientific collaboration semantic analysis synthesis': '0.03%', 'crowdsourcing land cover land use validation volunteered geographic information': '0.03%', 'citizen science co design crowd science science and innovation studies science education sustainability transitions': '0.03%', 'affective computing knowledge based real world applications mcda methods neuro decision matrix property': '0.03%', 'empowerment governance societal challenges transformative change transformative social innovation': '0.03%', 'bibliometrics china clustering computational linguistics india metrics research evaluation science and technology technology assessment text mining': '0.03%'}

# %% [markdown]
# Embedding

# %%
#user_id와 movie_id를 숫자형으로 변환
base_df['author_id'] = base_df['author_id'].astype(int)
base_df['paper_id'] = base_df['paper_id'].astype(int)
paper_ids = base_df.groupby(['author_id'])['paper_id'].apply(list).reset_index()  #user기준으로 grouping
print(paper_ids.shape)
paper_ids.head(2)
# Out:
# (25959, 2)
#     author_id      paper_id
# 0  6503876395          [66]
# 1  6503877646  [3886, 4758]

# %%
import matplotlib.pyplot as plt

# "paper_id" 열의 길이(데이터의 수)를 히스토그램으로 그리기
id_lengths = paper_ids["paper_id"].apply(lambda x: len(x))
filtered_id_lengths = [length for length in id_lengths if length > 6]
plt.hist(filtered_id_lengths, bins = 100)
plt.title('Histogram of paper_ids')
plt.xlabel('Number of paper_id')
plt.ylabel('Frequency')
plt.show()

# %%
# 명목형 변수 정수 인코딩
label_encoder = LabelEncoder()
base_df['source'] = label_encoder.fit_transform(base_df['source'])
source_hist = base_df.groupby(['author_id'])['source'].apply(list).reset_index()
source_hist['source'] = source_hist['source'].apply(lambda x: list(set(x)))
source_hist.sample(5)
# Out:
#          author_id   source
# 254     6506176370     [13]
# 1558    6603435002  [0, 11]
# 22486  57214875134      [0]
# 13744  55636747100      [3]
# 17085  56856256100     [11]

# %%
# 연속형 변수 스케일링
scaler = MinMaxScaler()
base_df['year'] = base_df['year'].astype(int)
base_df['paper_age'] = scaler.fit_transform(base_df['year'].values.reshape(-1, 1))
age_hist = base_df.groupby(['author_id'])['paper_age'].apply(list).reset_index()
age_hist.head(2)
# Out:
#     author_id                                  paper_age
# 0  6503876395                                      [0.0]
# 1  6503877646  [0.4210526315789451, 0.47368421052631504]

# %%
# 연속형 변수 스케일링
scaler = MinMaxScaler()
base_df['citation'] = base_df['citation'].astype(int)
base_df['citation'] = scaler.fit_transform(base_df['citation'].values.reshape(-1, 1))
citation_hist = base_df.groupby(['author_id'])['citation'].apply(list).reset_index()
citation_hist.head()
# Out:
#     author_id                                         citation
# 0  6503876395                           [0.004935459377372818]
# 1  6503877646     [0.016704631738800303, 0.004935459377372818]
# 2  6503897769                           [0.014806378132118452]
# 3  6503925997                          [0.0022779043280182236]
# 4  6503936010  [0.0007593014426727411, 0.00037965072133637056]

# %% [markdown]
# context-based embedding 1 - BERT, SciBERT
# - SciBERT: https://github.com/allenai/scibert/

# %%
tokenizer_bert = BertTokenizer.from_pretrained("bert-base-uncased")
tokenizer_scibert = AutoTokenizer.from_pretrained('allenai/scibert_scivocab_uncased')

# %%
#context-based embedding 1 - BERT, SciBERT

def emb_bert(text, tokenizer):
  key_emb = ""
  embs = []
  tokens = tokenizer.tokenize(text)
  for tok in tokens:
    key_emb = tokenizer.vocab[tok]
    embs.append(key_emb)
  return embs

keywords = base_df.groupby('author_id')['keywords_'].apply(lambda x: ' '.join(x)).reset_index()
keywords['keywords_'] = keywords['keywords_'].apply(lambda x : emb_bert(x, tokenizer_scibert))  #100개 18초
keywords_scibert = keywords
keywords_scibert.to_csv('keywords_scibert.csv', index=False)
keywords
# Out:
#          author_id                                          keywords_
# 0       6503876395  [4379, 6791, 5676, 17618, 8527, 6392, 2340, 76...
# 1       6503877646  [7827, 3439, 342, 2899, 4483, 1904, 8797, 6795...
# 2       6503897769                     [7266, 4548, 22811, 952, 3948]
# 3       6503925997                          [7549, 13817, 7425, 4673]
# 4       6503936010  [2870, 3672, 10814, 2753, 6163, 7381, 23065, 2...
# ...            ...                                                ...
# 25954  58029375900  [6771, 1139, 849, 2166, 21789, 5212, 428, 1144...
# 25955  58030387100  [6771, 1139, 849, 2166, 21789, 5212, 428, 1144...
# 25956  58030505000  [24648, 453, 1262, 2839, 3838, 9675, 3997, 190...
# 25957  58032445800  [4143, 451, 670, 14933, 28364, 1767, 934, 1187...
# 25958  58033752300  [3306, 669, 128, 30132, 30118, 1194, 25092, 55...
#
# [25959 rows x 2 columns]

# %% [markdown]
# context-based embedding 2 - doc2vec

# %%
#context-based embedding 2 - doc2vec
corpus = base_df.drop_duplicates(subset='paper_id', keep='first')
corpus['keywords'] = corpus['keywords'].apply(lambda x: x.split("; "))
corpus = corpus[["paper_id", "keywords"]]
corpus = corpus.dropna()
print(corpus.shape)
corpus.tail(3)
# Out:
# (15432, 2)
#        paper_id                                           keywords
# 43204     15430  [aviation, pharmaceuticals, regulation, techno...
# 43206     15431  [business angel, exit, financial resources, in...
# 43209     15432  [motivation-opportunity-ability framework, org...

# %%
tagged_corpus_list = []

for index, row in tqdm(corpus.iterrows(), total=len(corpus)):
  text = row['keywords']
  tag = row['paper_id']
  tagged_corpus_list.append(TaggedDocument(tags=[tag], words=text))

print('논문의 수 :', len(tagged_corpus_list))
# Out:
# 100%|██████████| 15432/15432 [00:00<00:00, 23224.16it/s]
# 논문의 수 : 15432

# %%
#Doc2Vec 학습
model = doc2vec.Doc2Vec(vector_size=1, alpha=0.025, min_alpha=0.025, workers=8, window=8)

# Vocabulary 빌드
model.build_vocab(tagged_corpus_list)
#print(f"Tag Size: {len(model.docvecs.doctags.keys())}", end=' / ')

# Doc2Vec 학습
model.train(tagged_corpus_list, total_examples=model.corpus_count, epochs=50)

# 모델 저장
model.save('keywords_1d.doc2vec')

# %%
#%cd doc2vec
vocabulary = list(model.wv.index_to_key)
print("Vocabulary:")
for word in vocabulary[:10]:
    print(word)
# Out:
# Vocabulary:
# innovation
# technology transfer
# china
# patents
# open innovation
# technological innovation
# entrepreneurship
# r&d
# sustainability
# innovation policy

# %%
similar_doc = model.docvecs.most_similar(1)
print(similar_doc)
# Out:
# [(9936, 1.0), (9934, 1.0), (9940, 1.0), (9939, 1.0), (9938, 1.0), (9937, 1.0), (9942, 1.0), (9930, 1.0), (9932, 1.0), (9943, 1.0)]

# %%
#1번 논문의 임베딩
model.docvecs[1]
# Out:
# array([0.24068373], dtype=float32)

# %%
doc_embeddings = []
paper_ids = []

for doc_id in range(1, len(corpus) + 1):
    paper_ids.append(doc_id)
    doc_embedding = model.dv[doc_id]
    doc_embeddings.append(doc_embedding)

# DataFrame으로 변환
data = {'paper_id': paper_ids, 'doc2vec': doc_embeddings}
df = pd.DataFrame(data)
df
# Out:
#        paper_id          doc2vec
# 0             1     [0.24068373]
# 1             2  [-0.0018035509]
# 2             3     [0.24186914]
# 3             4      [0.3566116]
# 4             5     [0.43833438]
# ...         ...              ...
# 15427     15428     [0.31285062]
# 15428     15429    [-0.09580643]
# 15429     15430     [0.36584952]
# 15430     15431     [0.49413013]
# 15431     15432     [0.35881782]
#
# [15432 rows x 2 columns]

# %%
df['doc2vec'] = df['doc2vec'].astype(float)
df
# Out:
#        paper_id   doc2vec
# 0             1  0.240684
# 1             2 -0.001804
# 2             3  0.241869
# 3             4  0.356612
# 4             5  0.438334
# ...         ...       ...
# 15427     15428  0.312851
# 15428     15429 -0.095806
# 15429     15430  0.365850
# 15430     15431  0.494130
# 15431     15432  0.358818
#
# [15432 rows x 2 columns]

# %%
df['doc_emb_m'] = df['doc2vec_embedding'].apply(lambda x: np.mean(x, axis=0))
df['doc_emb_s'] = df['doc2vec_embedding'].apply(lambda x: np.sum(x, axis=0))
df
# Out:
#        paper_id                                  doc2vec_embedding  doc_emb_m  \
# 0             1  [-0.16338906, -0.09241974, 0.0067125503, 0.040...   0.003812
# 1             2  [-0.0006986317, 0.04648378, -0.025559062, 0.08...   0.000591
# 2             3  [0.04991681, -0.030519081, -0.00023159268, -0....   0.000116
# 3             4  [-0.00036991, 0.0005857905, -0.0018949214, 0.0...   0.000041
# 4             5  [0.08658479, 0.07478007, 0.12653302, 0.1127374...  -0.007126
# ...         ...                                                ...        ...
# 15427     15428  [-0.06866682, 0.045954183, -0.022422474, -0.19...  -0.004852
# 15428     15429  [-0.07635487, 0.087850206, 0.009593916, -0.072...   0.004312
# 15429     15430  [-0.060306698, 0.020577285, 0.057892404, -0.21...   0.010324
# 15430     15431  [-0.03208177, 0.1003109, 0.0068312297, 0.05531...   0.004430
# 15431     15432  [-0.063534155, 0.2055448, -0.015311894, -0.047...  -0.001493
#
#        doc_emb_s
# 0       1.143567
# 1       0.177231
# 2       0.034773
# 3       0.012387
# 4      -2.137730
# ...          ...
# 15427  -1.455637
# 15428   1.293571
# 15429   3.097109
# 15430   1.328984
# 15431  -0.447973
#
# [15432 rows x 4 columns]

# %%
base_df = pd.merge(base_df, df, on = 'paper_id', how = 'left')
print(base_df.shape)
base_df.sample(3)
# Out:
# (43212, 19)
#        old_paper_id  paper_id    author_id author_type  \
# 27981         11405     10811  57533601600           5
# 997            9230       495   7006258746           5
# 43118         16291     15409  57201376672           3
#
#                                                    title  year  source  \
# 27981  internet adoption and financial development in...  2020      11
# 997    human capital heterogeneity collaborative rela...  2004       9
# 43118  the drivers of the digital transformation in t...  2022      13
#
#        citation                                           abstract  \
# 27981  0.008732  information and communications technology ict ...
# 997    0.039484  in this paper we compare the publication outco...
# 43118  0.000759  in recent years driven by the spread of the co...
#
#                                                 keywords  \
# 27981  economic freedom; financial development; human...
# 997    alliance; collaboration; human capital; knowle...
# 43118  digital transformation; digitalisation; health...
#
#                                                keywords_  write  paper_age  \
# 27981  economic freedom financial development human c...      1   0.894737
# 997    alliance collaboration human capital knowledge...      1   0.052632
# 43118  digital transformation digitalisation healthca...      1   1.000000
#
#                                      doc2vec_embedding_x  \
# 27981  [-0.044431612, 0.014842663, 0.06326422, 0.0807...
# 997    [-0.15876544, 0.14636709, 0.07240024, 0.162385...
# 43118  [-0.0017136047, 0.14376356, -0.031006461, 0.06...
#
#                                      doc2vec_embedding_y  doc_emb_m  \
# 27981  [-0.044431612, 0.014842663, 0.06326422, 0.0807...   0.000456
# 997    [-0.15876544, 0.14636709, 0.07240024, 0.162385...  -0.000327
# 43118  [-0.0017136047, 0.14376356, -0.031006461, 0.06...  -0.001421
#
#        doc_emb_s    doc2vec_x  doc2vec_y
# 27981   0.136915  [0.0871951]   0.087195
# 997    -0.098065  [0.3209306]   0.320931
# 43118  -0.426289  [0.9289418]   0.928942

# %%
keywords = base_df.groupby(['author_id'])['doc2vec_y'].apply(list).reset_index()
keywords
# Out:
#          author_id                                  doc2vec_y
# 0       6503876395                       [0.5925654172897339]
# 1       6503877646  [-0.21806655824184418, 1.016183853149414]
# 2       6503897769                       [0.5237812995910645]
# 3       6503925997                       [0.5780498385429382]
# 4       6503936010   [0.8798040747642517, 0.3966626226902008]
# ...            ...                                        ...
# 25954  58029375900                        [0.477058470249176]
# 25955  58030387100                        [0.477058470249176]
# 25956  58030505000                       [0.7352867722511292]
# 25957  58032445800                       [0.8444942831993103]
# 25958  58033752300                       [0.2203482985496521]
#
# [25959 rows x 2 columns]

# %% [markdown]
# Embedding합치기

# %%
#input_embedding만들기

input_embedding = keywords[['author_id']].drop_duplicates()
#input_embedding = pd.merge(input_embedding, cont_emb, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, paper_ids, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, source_hist, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, age_hist, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, citation_hist, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, keywords, on = 'author_id', how = 'left')

input_embedding
# Out:
#          author_id       paper_id   source  \
# 0       6503876395           [66]      [3]
# 1       6503877646   [3886, 4758]  [9, 12]
# 2       6503897769          [641]     [13]
# 3       6503925997          [906]     [11]
# 4       6503936010  [9804, 12321]     [11]
# ...            ...            ...      ...
# 25954  58029375900        [14035]      [8]
# 25955  58030387100        [14035]      [8]
# 25956  58030505000        [13408]      [0]
# 25957  58032445800        [15380]     [13]
# 25958  58033752300        [10970]     [11]
#
#                                        paper_age  \
# 0                                          [0.0]
# 1      [0.4210526315789451, 0.47368421052631504]
# 2                          [0.05263157894736992]
# 3                          [0.10526315789473983]
# 4       [0.8421052631578902, 0.9473684210526301]
# ...                                          ...
# 25954                                      [1.0]
# 25955                                      [1.0]
# 25956                                      [1.0]
# 25957                                      [1.0]
# 25958                       [0.8947368421052602]
#
#                                               citation  \
# 0                               [0.004935459377372818]
# 1         [0.016704631738800303, 0.004935459377372818]
# 2                               [0.014806378132118452]
# 3                              [0.0022779043280182236]
# 4      [0.0007593014426727411, 0.00037965072133637056]
# ...                                                ...
# 25954                          [0.0011389521640091118]
# 25955                          [0.0011389521640091118]
# 25956                                            [0.0]
# 25957                                            [0.0]
# 25958                           [0.006074411541381929]
#
#                                                keywords_
# 0      [4379, 6791, 5676, 17618, 8527, 6392, 2340, 76...
# 1      [7827, 3439, 342, 2899, 4483, 1904, 8797, 6795...
# 2                         [7266, 4548, 22811, 952, 3948]
# 3                              [7549, 13817, 7425, 4673]
# 4      [2870, 3672, 10814, 2753, 6163, 7381, 23065, 2...
# ...                                                  ...
# 25954  [6771, 1139, 849, 2166, 21789, 5212, 428, 1144...
# 25955  [6771, 1139, 849, 2166, 21789, 5212, 428, 1144...
# 25956  [24648, 453, 1262, 2839, 3838, 9675, 3997, 190...
# 25957  [4143, 451, 670, 14933, 28364, 1767, 934, 1187...
# 25958  [3306, 669, 128, 30132, 30118, 1194, 25092, 55...
#
# [25959 rows x 6 columns]

# %%
#과거데이터 만들기-1
input_embedding_d_1 = input_embedding[['author_id']].drop_duplicates()
input_embedding_d_1['write_hist'] = input_embedding['paper_id'].apply(lambda x : x[:-1])

input_embedding_d_1['source'] = input_embedding['source'].apply(lambda x : x[:-1])
input_embedding_d_1['paper_age'] = input_embedding['paper_age'].apply(lambda x : x[:-1])
input_embedding_d_1['citation'] = input_embedding['citation'].apply(lambda x : x[:-1])

#predict_labels만들기 (write_hist의 마지막 값)
input_embedding_d_1['predict_labels'] = input_embedding['paper_id'].apply(lambda x : x[-1])

#print(input_embedding.shape)
input_embedding_d_1.tail(3)
# Out:
#          author_id write_hist source paper_age citation  predict_labels
# 25956  57217486655         []     []        []       []           15432
# 25957  55768922000         []     []        []       []           15432
# 25958  57188726348         []     []        []       []           15433

# %%
input_embedding_dd = input_embedding_d_1[input_embedding_d_1['write_hist'].apply(lambda x: bool(x))]
#input_embedding_dd.to_csv('input_embedding_dd.csv', index=False)
print(input_embedding_dd.shape)
input_embedding_dd.tail(3)
# Out:
# (6675, 6)
#          author_id write_hist source paper_age                 citation  \
# 25745  57202199330    [15293]   [13]     [1.0]  [0.0022779043280182236]
# 25778  56982304200    [15318]   [13]     [1.0]                    [0.0]
# 25807  57208108972    [15338]   [13]     [1.0]                    [0.0]
#
#        predict_labels
# 25745           15370
# 25778           15429
# 25807           15389

# %%
#과거데이터 만들기_2
input_embedding_d_2 = input_embedding[['author_id']].drop_duplicates()
input_embedding_d_2['write_hist'] = input_embedding['paper_id'].apply(lambda x : x[:-1])

input_embedding_d_2['source'] = input_embedding['source']
input_embedding_d_2['paper_age'] = input_embedding['paper_age'].apply(lambda x : x[:-1])
input_embedding_d_2['citation'] = input_embedding['citation'].apply(lambda x : x[:-1])
input_embedding_d_2['keywords'] = input_embedding['keywords_']

#predict_labels만들기 (write_hist의 마지막 값)
input_embedding_d_2['predict_labels'] = input_embedding['paper_id'].apply(lambda x : x[-1])

#print(input_embedding.shape)
input_embedding_d_2
# Out:
#          author_id write_hist   source             paper_age  \
# 0       6503876395         []      [3]                    []
# 1       6503877646     [3886]  [9, 12]  [0.4210526315789451]
# 2       6503897769         []     [13]                    []
# 3       6503925997         []     [11]                    []
# 4       6503936010     [9804]     [11]  [0.8421052631578902]
# ...            ...        ...      ...                   ...
# 25954  58029375900         []      [8]                    []
# 25955  58030387100         []      [8]                    []
# 25956  58030505000         []      [0]                    []
# 25957  58032445800         []     [13]                    []
# 25958  58033752300         []     [11]                    []
#
#                       citation  \
# 0                           []
# 1       [0.016704631738800303]
# 2                           []
# 3                           []
# 4      [0.0007593014426727411]
# ...                        ...
# 25954                       []
# 25955                       []
# 25956                       []
# 25957                       []
# 25958                       []
#
#                                                 keywords  predict_labels
# 0      [4379, 6791, 5676, 17618, 8527, 6392, 2340, 76...              66
# 1      [7827, 3439, 342, 2899, 4483, 1904, 8797, 6795...            4758
# 2                         [7266, 4548, 22811, 952, 3948]             641
# 3                              [7549, 13817, 7425, 4673]             906
# 4      [2870, 3672, 10814, 2753, 6163, 7381, 23065, 2...           12321
# ...                                                  ...             ...
# 25954  [6771, 1139, 849, 2166, 21789, 5212, 428, 1144...           14035
# 25955  [6771, 1139, 849, 2166, 21789, 5212, 428, 1144...           14035
# 25956  [24648, 453, 1262, 2839, 3838, 9675, 3997, 190...           13408
# 25957  [4143, 451, 670, 14933, 28364, 1767, 934, 1187...           15380
# 25958  [3306, 669, 128, 30132, 30118, 1194, 25092, 55...           10970
#
# [25959 rows x 7 columns]

# %%
input_embedding_dd = input_embedding_d_2[input_embedding_d_2['write_hist'].apply(lambda x: bool(x))]
#input_embedding_dd.to_csv('input_embedding_dd.csv', index=False)
print(input_embedding_dd.shape)
input_embedding_dd.tail(3)
# Out:
# (6675, 7)
#          author_id write_hist   source             paper_age  \
# 25738  57865641400    [13476]  [0, 13]                 [1.0]
# 25763  57874921300     [7783]      [0]  [0.7368421052631504]
# 25893  57955355500    [13412]      [0]                 [1.0]
#
#                       citation  \
# 25738                    [0.0]
# 25763  [0.0018982536066818527]
# 25893                    [0.0]
#
#                                                 keywords  predict_labels
# 25738  [4966, 8476, 5860, 3650, 2378, 2404, 2647, 230...           15423
# 25763  [3948, 624, 1837, 2460, 131, 16637, 15090, 365...            9356
# 25893  [21004, 173, 371, 21004, 173, 371, 21238, 1744...           13455

# %%
train_data, test_data = train_test_split(input_embedding_d_2, test_size=0.2, random_state=1234) #random_state
print(train_data.shape)  #(20767, 6)
print(test_data.shape)   #(5192, 6)
# Out:
# (20767, 7)
# (5192, 7)

# %%
train_data, test_data = train_test_split(input_embedding_dd, test_size=0.2, random_state=1234) #random_state
print(train_data.shape)  #(5340, 7)
print(test_data.shape)   #(1335, 7)
# Out:
# (5340, 7)
# (1335, 7)

# %%
train_data.sample(2)
# Out:
#          author_id write_hist source paper_age citation  \
# 18171  57190189250         []   [11]        []       []
# 25703  57847410000         []    [0]        []       []
#
#                                                 keywords  predict_labels
# 18171  [400, 3547, 437, 190, 4550, 3794, 304, 30132, ...            9875
# 25703  [3948, 3948, 16865, 28864, 12833, 1288, 21004,...           13555

# %%
test_data.sample(2)
# Out:
#          author_id                write_hist source  \
# 14971  56001395400                        []   [12]
# 4924    8842403100  [5657, 6383, 7169, 7179]    [8]
#
#                                                paper_age  \
# 14971                                                 []
# 4924   [0.5789473684210549, 0.6315789473684106, 0.684...
#
#                                                 citation  \
# 14971                                                 []
# 4924   [0.0037965072133637054, 0.035687167805618834, ...
#
#                                                 keywords  predict_labels
# 14971         [3580, 7270, 3948, 437, 3787, 3502, 28815]           13030
# 4924   [4740, 699, 1798, 453, 1422, 9997, 6522, 8656,...            9565

# %%
print(train_data.iloc[35])
# Out:
# author_id                                               55813626200
# write_hist                                                  [11410]
# source                                                          [0]
# paper_age                                      [0.9473684210526301]
# citation                                     [0.006074411541381929]
# keywords          [10733, 1013, 869, 17001, 437, 869, 12445, 437...
# predict_labels                                                13234
# Name: 14271, dtype: object

# %% [markdown]
# Model

# %%
#들어온 embedding값을 평균내는 클래스
class MaskedEmbeddingsAggregatorLayer(keras.layers.Layer):
  def __init__(self, agg_mode = 'mean', **kwargs):
    super(MaskedEmbeddingsAggregatorLayer, self).__init__(**kwargs)
    self.agg_mode = agg_mode

  @tf.function
  def call(self, inputs, mask = None):  #feedforward
    masked_embeddings = tf.ragged.boolean_mask(inputs, mask)  #입력 임베딩 masking
    #print("masked_embeddings:", masked_embeddings)
    aggregated = tf.reduce_mean(inputs, axis = 1)  #평균
    print("aggregated:", aggregated)
    return aggregated

  def get_config(self):
    return {'agg_mode' : self.agg_mode}


#L2NormLayer적용하는 클래스
class L2NormLayer(keras.layers.Layer):
  def __init__(self, **kwargs):
    super(L2NormLayer, self).__init__(**kwargs)

  @tf.function
  def call(self, inputs, mask = None):
    if mask is None:  #mask가 none이 아니면 mask 적용
      inputs = tf.ragged.boolean_mask(inputs, mask).to_tensor()

    return tf.math.l2_normalize(inputs, axis = -1)

  def compute_mask(self, inputs, mask):  #mask반환하기 위해서
    #print(mask)
    return mask

# %% [markdown]
# Candidate generation
# ~~~python
# INPUT_LIST: ['write_hist', 'paper_age', 'source', 'citation']
# input_shape: Tensor("IteratorGetNext:0", shape=(20767, 54), dtype=int32)
# embedding_out_1: Tensor("candidate_generation/embedding/embedding_lookup/Identity_1:0", shape=(20767, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation/masked_embeddings_aggregator_layer/PartitionedCall:0", shape=(20767, 16), dtype=float32)
# embedding_out_2: Tensor("candidate_generation/embedding/embedding_lookup_1/Identity_1:0", shape=(20767, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation/masked_embeddings_aggregator_layer/PartitionedCall_1:0", shape=(20767, 16), dtype=float32)
# embedding_out_3: Tensor("candidate_generation/embedding/embedding_lookup_2/Identity_1:0", shape=(20767, 55, 16), dtype=float32)
# avg_features: Tensor("candidate_generation/masked_embeddings_aggregator_layer/PartitionedCall_2:0", shape=(20767, 16), dtype=float32)
# embedding_out_4: Tensor("candidate_generation/embedding/embedding_lookup_3/Identity_1:0", shape=(20767, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation/masked_embeddings_aggregator_layer/PartitionedCall_3:0", shape=(20767, 16), dtype=float32)
# concat_inputs: (20767, 64)
# dense_features_1024: Tensor("candidate_generation/dense/BiasAdd:0", shape=(20767, 1024), dtype=float32)
# dense_features_512: Tensor("candidate_generation/dense_1/BiasAdd:0", shape=(20767, 512), dtype=float32)
# dense_features_256: Tensor("candidate_generation/dense_2/BiasAdd:0", shape=(20767, 256), dtype=float32)
# OUTPUTS: (20767, 15434)
# ~~~

# %%
NUM_CLASSES = len(base_df['paper_id'].unique()) + 2   #base_df['paper_id'].max()+2
NUM_CLASSES  #15434
# Out:
# 15434

# %%
class CandidateGeneration(keras.Model):
  def __init__(self, inputs, embedding_dims):  #input과 embedding 차원을 받음
    super(CandidateGeneration, self).__init__()

    self.inputs = inputs
    self.embedding_dims = embedding_dims

    #input받은걸 4개로 나눔
    self.input_watch_hist, self.input_watch_hist_time, self.input_search_hist, self.input_example_age, self.input_keywords = self.inputs

    #embedding layer, aggregation layer 설정
    self.feature_embeddings = keras.layers.Embedding(input_dim = NUM_CLASSES, output_dim = embedding_dims, mask_zero = True, trainable = True)
    self.avg_embeddings = MaskedEmbeddingsAggregatorLayer(agg_mode = 'mean')

    #dense layer설정
    self.dense_layer_list = [keras.layers.Dense(units = i) for i in config.layers]
    self.dense_output = keras.layers.Dense(NUM_CLASSES, activation = 'softmax')

    #배치정규화
    self.batch_norm_layers = [keras.layers.BatchNormalization() for _ in range(3)]

  def call(self, inputs):
    input_watch_hist, input_watch_hist_time, input_search_hist, input_example_age, input_keywords = inputs
    print("input_shape:", input_watch_hist)

    avg_features = self.embeddings(input_watch_hist)
    avg_watches = self.embeddings(input_watch_hist_time)
    avg_searches = self.embeddings(input_search_hist)      #shape=(5340, 16)
    avg_example_age = self.embeddings(input_example_age)   #shape=(5340, 16)
    avg_keywords = self.embeddings(input_keywords)
    print("avg_keywords:", avg_keywords)


    #임베딩 합치기
    #concat_inputs = keras.layers.Concatenate(axis = 1)([avg_features, avg_watches, avg_searches, avg_example_age, avg_keywords])
    concat_inputs = keras.layers.Concatenate(axis = 1)([avg_features, avg_example_age, avg_keywords])

    print("concat_inputs:", concat_inputs.shape)
    results = concat_inputs   #shape=(5340, 64)

    #dense layer, batch normalization layer-> neural network통과
    for dense_layer, batch_norm_layer in zip(self.dense_layer_list, self.batch_norm_layers):
      dense_features = dense_layer(results)
      print("dense_features:", dense_features)
      dense_relu = keras.layers.ReLU()(dense_features)
      dense_batch_norm = batch_norm_layer(dense_relu)
      results = dense_batch_norm
      print("results:",results)

    outputs = self.dense_output(results)
    print("outputs:", outputs)
    return outputs

  def embeddings(self, input_feature):
    #print("input_feature_in_emb:", input_feature)
    embeddings = self.feature_embeddings(input_feature)
    print("embedding_out:", embeddings)
    l2_norm_features = L2NormLayer()(embeddings)
    avg_features = self.avg_embeddings(l2_norm_features)
    print("avg_features:", avg_features)

    return avg_features

# %%
config = {
    'epochs': 100,
    'top_k':10,
    'lr' : 0.001,
    'embedding_dims' : 16,
    'dense_units' : 64,
    'layers': [512, 256, 128]#[1024, 512, 256]
}

config = Box(config)

#input선언 및 초기화
input_watch_hist = keras.layers.Input(shape = (None,))
input_watch_hist_time = keras.layers.Input(shape = (None,))
input_search_hist = keras.layers.Input(shape = (None,))
input_example_age = keras.layers.Input(shape = (None,))
input_keywords = keras.layers.Input(shape = (None,))

#초기화 해서 input list에 넣어줌
inputs = [input_watch_hist, input_watch_hist_time, input_search_hist, input_example_age, input_keywords]

model = CandidateGeneration(inputs, config.embedding_dims)
model.compile(optimizer = keras.optimizers.Adam(learning_rate = config.lr),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['acc'])

batch_size = 32
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

max_lenth = 20

history = model.fit([sequence.pad_sequences(train_data['write_hist']),
                     sequence.pad_sequences(train_data['paper_age'], dtype = float),
                     sequence.pad_sequences(train_data['source']),
                     sequence.pad_sequences(train_data['citation'], dtype = float),
                     sequence.pad_sequences(train_data['keywords'], dtype = float)],
                    train_data['predict_labels'].values,
                    steps_per_epoch = 100, epochs = config.epochs) #, callbacks=[early_stopping] )#batch_size = batch_size, )
# Out:
# Epoch 1/100
# input_shape: Tensor("IteratorGetNext:0", shape=(None, 54), dtype=int32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_1/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_1:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_2/Identity_1:0", shape=(None, 10, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_2:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_3/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_3:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_4/Identity_1:0", shape=(None, 765, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# avg_keywords: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# concat_inputs: (None, 48)
# dense_features: Tensor("candidate_generation_16/dense_56/BiasAdd:0", shape=(None, 512), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_48/batchnorm/add_1:0", shape=(None, 512), dtype=float32)
# dense_features: Tensor("candidate_generation_16/dense_57/BiasAdd:0", shape=(None, 256), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_49/batchnorm/add_1:0", shape=(None, 256), dtype=float32)
# dense_features: Tensor("candidate_generation_16/dense_58/BiasAdd:0", shape=(None, 128), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_50/batchnorm/add_1:0", shape=(None, 128), dtype=float32)
# outputs: Tensor("candidate_generation_16/dense_59/Softmax:0", shape=(None, 15434), dtype=float32)
# input_shape: Tensor("IteratorGetNext:0", shape=(None, 54), dtype=int32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_1/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_1:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_2/Identity_1:0", shape=(None, 10, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_2:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_3/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_3:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_4/Identity_1:0", shape=(None, 765, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# avg_keywords: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# concat_inputs: (None, 48)
# dense_features: Tensor("candidate_generation_16/dense_56/BiasAdd:0", shape=(None, 512), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_48/batchnorm/add_1:0", shape=(None, 512), dtype=float32)
# dense_features: Tensor("candidate_generation_16/dense_57/BiasAdd:0", shape=(None, 256), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_49/batchnorm/add_1:0", shape=(None, 256), dtype=float32)
# dense_features: Tensor("candidate_generation_16/dense_58/BiasAdd:0", shape=(None, 128), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_50/batchnorm/add_1:0", shape=(None, 128), dtype=float32)
# outputs: Tensor("candidate_generation_16/dense_59/Softmax:0", shape=(None, 15434), dtype=float32)
# 100/100 [==============================] - 16s 129ms/step - loss: 9.4703 - acc: 0.0061
# Epoch 2/100
# 100/100 [==============================] - 10s 96ms/step - loss: 8.3001 - acc: 0.0330
# Epoch 3/100
# 100/100 [==============================] - 8s 75ms/step - loss: 6.8301 - acc: 0.1296
# Epoch 4/100
# 100/100 [==============================] - 6s 62ms/step - loss: 5.3295 - acc: 0.3051
# Epoch 5/100
# 100/100 [==============================] - 7s 67ms/step - loss: 3.9355 - acc: 0.5039
# Epoch 6/100
# 100/100 [==============================] - 4s 45ms/step - loss: 2.7451 - acc: 0.6633
# Epoch 7/100
# 100/100 [==============================] - 3s 33ms/step - loss: 1.7935 - acc: 0.7935
# Epoch 8/100
# 100/100 [==============================] - 3s 33ms/step - loss: 1.1097 - acc: 0.9043
# Epoch 9/100
# 100/100 [==============================] - 3s 35ms/step - loss: 0.6582 - acc: 0.9680
# Epoch 10/100
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3873 - acc: 0.9902
# Epoch 11/100
# 100/100 [==============================] - 2s 25ms/step - loss: 0.2308 - acc: 0.9970
# Epoch 12/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1477 - acc: 0.9988
# Epoch 13/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1032 - acc: 0.9997
# Epoch 14/100
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0781 - acc: 0.9996
# Epoch 15/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0608 - acc: 0.9997
# Epoch 16/100
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0500 - acc: 0.9997
# Epoch 17/100
# 100/100 [==============================] - 2s 23ms/step - loss: 0.0418 - acc: 0.9998
# Epoch 18/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0340 - acc: 0.9998
# Epoch 19/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0310 - acc: 0.9998
# Epoch 20/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0262 - acc: 0.9999
# Epoch 21/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0242 - acc: 0.9998
# Epoch 22/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0206 - acc: 0.9998
# Epoch 23/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0182 - acc: 0.9999
# Epoch 24/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0170 - acc: 0.9998
# Epoch 25/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0169 - acc: 0.9998
# Epoch 26/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0140 - acc: 0.9999
# Epoch 27/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0377 - acc: 0.9975
# Epoch 28/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0794 - acc: 0.9919
# Epoch 29/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0760 - acc: 0.9923
# Epoch 30/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0444 - acc: 0.9967
# Epoch 31/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0284 - acc: 0.9977
# Epoch 32/100
# 100/100 [==============================] - 2s 15ms/step - loss: 0.0184 - acc: 0.9989
# Epoch 33/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0108 - acc: 0.9994
# Epoch 34/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0071 - acc: 0.9999
# Epoch 35/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0059 - acc: 0.9999
# Epoch 36/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0055 - acc: 0.9999
# Epoch 37/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0050 - acc: 0.9999
# Epoch 38/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0045 - acc: 0.9999
# Epoch 39/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0040 - acc: 0.9999
# Epoch 40/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0039 - acc: 0.9999
# Epoch 41/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0036 - acc: 1.0000
# Epoch 42/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0037 - acc: 0.9999
# Epoch 43/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0031 - acc: 0.9999
# Epoch 44/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0030 - acc: 0.9999
# Epoch 45/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0028 - acc: 0.9999
# Epoch 46/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0027 - acc: 1.0000
# Epoch 47/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0024 - acc: 0.9999
# Epoch 48/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0023 - acc: 0.9999
# Epoch 49/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0022 - acc: 1.0000
# Epoch 50/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0022 - acc: 0.9999
# Epoch 51/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0020 - acc: 0.9999
# Epoch 52/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0019 - acc: 0.9999
# Epoch 53/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0018 - acc: 1.0000
# Epoch 54/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0024 - acc: 0.9999
# Epoch 55/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0021 - acc: 1.0000
# Epoch 56/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0018 - acc: 0.9999
# Epoch 57/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0019 - acc: 0.9999
# Epoch 58/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0015 - acc: 0.9999
# Epoch 59/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0013 - acc: 0.9999
# Epoch 60/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0012 - acc: 1.0000
# Epoch 61/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0012 - acc: 1.0000
# Epoch 62/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0012 - acc: 1.0000
# Epoch 63/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0011 - acc: 1.0000
# Epoch 64/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0012 - acc: 0.9999
# Epoch 65/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0900 - acc: 0.9828
# Epoch 66/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3579 - acc: 0.9183
# Epoch 67/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.1172 - acc: 0.9762
# Epoch 68/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0261 - acc: 0.9950
# Epoch 69/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0165 - acc: 0.9975
# Epoch 70/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0067 - acc: 0.9991
# Epoch 71/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0045 - acc: 0.9994
# Epoch 72/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0038 - acc: 0.9996
# Epoch 73/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0020 - acc: 0.9998
# Epoch 74/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0017 - acc: 0.9998
# Epoch 75/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0016 - acc: 0.9998
# Epoch 76/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0014 - acc: 0.9999
# Epoch 77/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0010 - acc: 0.9999
# Epoch 78/100
# 100/100 [==============================] - 1s 11ms/step - loss: 9.7602e-04 - acc: 1.0000
# Epoch 79/100
# 100/100 [==============================] - 1s 9ms/step - loss: 8.6422e-04 - acc: 1.0000
# Epoch 80/100
# 100/100 [==============================] - 1s 12ms/step - loss: 8.6021e-04 - acc: 1.0000
# Epoch 81/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0013 - acc: 0.9998
# Epoch 82/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0012 - acc: 0.9999
# Epoch 83/100
# 100/100 [==============================] - 1s 9ms/step - loss: 8.4185e-04 - acc: 0.9999
# Epoch 84/100
# 100/100 [==============================] - 1s 14ms/step - loss: 9.7309e-04 - acc: 0.9999
# Epoch 85/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0015 - acc: 0.9998
# Epoch 86/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0049 - acc: 0.9993
# Epoch 87/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0117 - acc: 0.9980
# Epoch 88/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0230 - acc: 0.9954
# Epoch 89/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0202 - acc: 0.9962
# Epoch 90/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0234 - acc: 0.9970
# Epoch 91/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0202 - acc: 0.9966
# Epoch 92/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0200 - acc: 0.9962
# Epoch 93/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0090 - acc: 0.9987
# Epoch 94/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0049 - acc: 0.9991
# Epoch 95/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0013 - acc: 0.9999
# Epoch 96/100
# 100/100 [==============================] - 1s 11ms/step - loss: 8.0678e-04 - acc: 1.0000
# Epoch 97/100
# 100/100 [==============================] - 1s 11ms/step - loss: 6.6759e-04 - acc: 0.9999
# Epoch 98/100
# 100/100 [==============================] - 1s 9ms/step - loss: 7.3628e-04 - acc: 1.0000
# Epoch 99/100
# 100/100 [==============================] - 1s 9ms/step - loss: 5.9507e-04 - acc: 0.9999
# Epoch 100/100
# 100/100 [==============================] - 1s 9ms/step - loss: 5.5254e-04 - acc: 0.9999

# %%
loss = pd.DataFrame.from_dict(history.history)
display(loss)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize = (10, 4))

ax[0].plot(history.history['acc'])
ax[0].set_title('Train Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')

ax[1].plot(history.history['loss'])
ax[1].set_title('Train Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')

fig.tight_layout()
plt.show()

# %%
model.save('candidate_0906_1540', save_format="tf")

# %%
# 테스트 데이터 준비 (예시)
#test_inputs = [test_data['write_hist'], test_data['paper_age'], test_data['source'], test_data['citation']]
#test_labels = test_data['predict_labels'].values

# 모델 평가
loss, accuracy = model.evaluate([sequence.pad_sequences(test_data['write_hist']),
                                 sequence.pad_sequences(test_data['paper_age'], dtype = float),
                                 sequence.pad_sequences(test_data['source']),
                                 sequence.pad_sequences(test_data['citation'], dtype = float),
                                 sequence.pad_sequences(test_data['keywords'])],
                                 test_data['predict_labels'].values, )

print(" Loss:",loss,"\n","Accuracy:", accuracy)
# Out:
# input_shape: Tensor("IteratorGetNext:0", shape=(None, 30), dtype=int32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup/Identity_1:0", shape=(None, 30, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_1/Identity_1:0", shape=(None, 30, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_1:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_2/Identity_1:0", shape=(None, 8, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_2:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_3/Identity_1:0", shape=(None, 30, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_3:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_16/embedding_16/embedding_lookup_4/Identity_1:0", shape=(None, 563, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# avg_keywords: Tensor("candidate_generation_16/masked_embeddings_aggregator_layer_16/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# concat_inputs: (None, 48)
# dense_features: Tensor("candidate_generation_16/dense_56/BiasAdd:0", shape=(None, 512), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_48/batchnorm/add_1:0", shape=(None, 512), dtype=float32)
# dense_features: Tensor("candidate_generation_16/dense_57/BiasAdd:0", shape=(None, 256), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_49/batchnorm/add_1:0", shape=(None, 256), dtype=float32)
# dense_features: Tensor("candidate_generation_16/dense_58/BiasAdd:0", shape=(None, 128), dtype=float32)
# results: Tensor("candidate_generation_16/batch_normalization_50/batchnorm/add_1:0", shape=(None, 128), dtype=float32)
# outputs: Tensor("candidate_generation_16/dense_59/Softmax:0", shape=(None, 15434), dtype=float32)
# 163/163 [==============================] - 1s 4ms/step - loss: 9.5867 - acc: 0.5614
#  Loss: 9.58674430847168
#  Accuracy: 0.5614407062530518

# %% [markdown]
# Feature = ["title", "abstract", "kewords"]

# %%
base_df.head(3)
# Out:
#    old_paper_id  paper_id    author_id author_type  \
# 0          1856         1   6602364830           3
# 1          1856         1  55662922800           2
# 2          1856         1   7103126830           1
#
#                                                title  year  source  citation  \
# 0  a multilevel analysis of factors influencing t...  2003       0  0.014047
# 1  a multilevel analysis of factors influencing t...  2003       0  0.014047
# 2  a multilevel analysis of factors influencing t...  2003       0  0.014047
#
#                                             abstract  \
# 0  the internet is an outcome of the convergence ...
# 1  the internet is an outcome of the convergence ...
# 2  the internet is an outcome of the convergence ...
#
#                                             keywords  \
# 0  banking industry; electronic commerce; multile...
# 1  banking industry; electronic commerce; multile...
# 2  banking industry; electronic commerce; multile...
#
#                                            keywords_  write  paper_age
# 0  banking industry electronic commerce multileve...      1        0.0
# 1  banking industry electronic commerce multileve...      1        0.0
# 2  banking industry electronic commerce multileve...      1        0.0

# %%
#base_df['features'] = base_df['title'] + ' ' + base_df['abstract'] + ' ' + base_df['keywords_']
base_df['features'] = base_df['title'] + ' ' + base_df['keywords_']
base_df['features'][0]
# Out:
# 'a multilevel analysis of factors influencing the adoption of internet banking banking industry electronic commerce multilevel analysis of technology adoption product and process innovations in user industries strategic change technological change technological innovation'

# %%
#context-based embedding
import pandas as pd
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def emb_bert(text):
  key_emb = ""
  embs = []
  tokens = tokenizer.tokenize(text)
  for tok in tokens:
    key_emb = tokenizer.vocab[tok]
    embs.append(key_emb)
  return embs

features = base_df.groupby('author_id')['features'].apply(lambda x: ' '.join(x)).reset_index()
features['features'] = features['features'].apply(lambda x : emb_bert(x))

features
# Out:
#          author_id                                           features
# 0       6503876395  [8144, 6194, 1999, 9677, 12906, 1997, 15488, 2...
# 1       6503877646  [5278, 1996, 3193, 1997, 3612, 2373, 2458, 206...
# 2       6503897769  [1996, 3466, 1997, 4816, 6236, 2006, 2235, 282...
# 3       6503925997  [2112, 28775, 4502, 7062, 4013, 26745, 10074, ...
# 4       6503936010  [24155, 1997, 15836, 3930, 1999, 1996, 8174, 3...
# ...            ...                                                ...
# 25954  58029375900  [9859, 2005, 9099, 10521, 6895, 28296, 5649, 2...
# 25955  58030387100  [9859, 2005, 9099, 10521, 6895, 28296, 5649, 2...
# 25956  58030505000  [8536, 17547, 2005, 6605, 4800, 26266, 2326, 3...
# 25957  58032445800  [13296, 3716, 6125, 3945, 1998, 4654, 24759, 6...
# 25958  58033752300  [2341, 2000, 2341, 3604, 1999, 18540, 2629, 39...
#
# [25959 rows x 2 columns]

# %%
#input_embedding만들기

input_embedding = keywords[['author_id']].drop_duplicates()
#input_embedding = pd.merge(input_embedding, cont_emb, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, paper_ids, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, source_hist, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, age_hist, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, citation_hist, on = 'author_id', how = 'left')
input_embedding = pd.merge(input_embedding, features, on = 'author_id', how = 'left')

input_embedding
# Out:
#          author_id       paper_id    source  \
# 0       6503876395           [66]       [3]
# 1       6503877646   [3886, 4758]   [9, 12]
# 2       6503897769          [641]      [13]
# 3       6503925997          [906]      [11]
# 4       6503936010  [9805, 12322]  [11, 11]
# ...            ...            ...       ...
# 25954  58029375900        [14036]       [8]
# 25955  58030387100        [14036]       [8]
# 25956  58030505000        [13409]       [0]
# 25957  58032445800        [15381]      [13]
# 25958  58033752300        [10971]      [11]
#
#                                        paper_age  \
# 0                                          [0.0]
# 1      [0.4210526315789451, 0.47368421052631504]
# 2                          [0.05263157894736992]
# 3                          [0.10526315789473983]
# 4       [0.8421052631578902, 0.9473684210526301]
# ...                                          ...
# 25954                                      [1.0]
# 25955                                      [1.0]
# 25956                                      [1.0]
# 25957                                      [1.0]
# 25958                       [0.8947368421052602]
#
#                                               citation  \
# 0                               [0.004935459377372818]
# 1         [0.016704631738800303, 0.004935459377372818]
# 2                               [0.014806378132118452]
# 3                              [0.0022779043280182236]
# 4      [0.0007593014426727411, 0.00037965072133637056]
# ...                                                ...
# 25954                          [0.0011389521640091118]
# 25955                          [0.0011389521640091118]
# 25956                                            [0.0]
# 25957                                            [0.0]
# 25958                           [0.006074411541381929]
#
#                                                 features
# 0      [8144, 6194, 1999, 9677, 12906, 1997, 15488, 2...
# 1      [5278, 1996, 3193, 1997, 3612, 2373, 2458, 206...
# 2      [1996, 3466, 1997, 4816, 6236, 2006, 2235, 282...
# 3      [2112, 28775, 4502, 7062, 4013, 26745, 10074, ...
# 4      [24155, 1997, 15836, 3930, 1999, 1996, 8174, 3...
# ...                                                  ...
# 25954  [9859, 2005, 9099, 10521, 6895, 28296, 5649, 2...
# 25955  [9859, 2005, 9099, 10521, 6895, 28296, 5649, 2...
# 25956  [8536, 17547, 2005, 6605, 4800, 26266, 2326, 3...
# 25957  [13296, 3716, 6125, 3945, 1998, 4654, 24759, 6...
# 25958  [2341, 2000, 2341, 3604, 1999, 18540, 2629, 39...
#
# [25959 rows x 6 columns]

# %%
#과거데이터 만들기_2
input_embedding_d_2 = input_embedding[['author_id']].drop_duplicates()
input_embedding_d_2['write_hist'] = input_embedding['paper_id'].apply(lambda x : x[:-1])
input_embedding_d_2['source'] = input_embedding['source']
input_embedding_d_2['paper_age'] = input_embedding['paper_age'].apply(lambda x : x[:-1])
input_embedding_d_2['citation'] = input_embedding['citation'].apply(lambda x : x[:-1])
input_embedding_d_2['features'] = input_embedding['features']

#predict_labels만들기 (write_hist의 마지막 값)
input_embedding_d_2['predict_labels'] = input_embedding['paper_id'].apply(lambda x : x[-1])

#print(input_embedding.shape)
input_embedding_d_2
# Out:
#          author_id write_hist    source             paper_age  \
# 0       6503876395         []       [3]                    []
# 1       6503877646     [3886]   [9, 12]  [0.4210526315789451]
# 2       6503897769         []      [13]                    []
# 3       6503925997         []      [11]                    []
# 4       6503936010     [9805]  [11, 11]  [0.8421052631578902]
# ...            ...        ...       ...                   ...
# 25954  58029375900         []       [8]                    []
# 25955  58030387100         []       [8]                    []
# 25956  58030505000         []       [0]                    []
# 25957  58032445800         []      [13]                    []
# 25958  58033752300         []      [11]                    []
#
#                       citation  \
# 0                           []
# 1       [0.016704631738800303]
# 2                           []
# 3                           []
# 4      [0.0007593014426727411]
# ...                        ...
# 25954                       []
# 25955                       []
# 25956                       []
# 25957                       []
# 25958                       []
#
#                                                 features  predict_labels
# 0      [8144, 6194, 1999, 9677, 12906, 1997, 15488, 2...              66
# 1      [5278, 1996, 3193, 1997, 3612, 2373, 2458, 206...            4758
# 2      [1996, 3466, 1997, 4816, 6236, 2006, 2235, 282...             641
# 3      [2112, 28775, 4502, 7062, 4013, 26745, 10074, ...             906
# 4      [24155, 1997, 15836, 3930, 1999, 1996, 8174, 3...           12322
# ...                                                  ...             ...
# 25954  [9859, 2005, 9099, 10521, 6895, 28296, 5649, 2...           14036
# 25955  [9859, 2005, 9099, 10521, 6895, 28296, 5649, 2...           14036
# 25956  [8536, 17547, 2005, 6605, 4800, 26266, 2326, 3...           13409
# 25957  [13296, 3716, 6125, 3945, 1998, 4654, 24759, 6...           15381
# 25958  [2341, 2000, 2341, 3604, 1999, 18540, 2629, 39...           10971
#
# [25959 rows x 7 columns]

# %%
train_data, test_data = train_test_split(input_embedding_d_2, test_size=0.2, random_state=1234) #random_state
print(train_data.shape)  #(20767, 6)
print(test_data.shape)   #(5192, 6)
# Out:
# (20767, 7)
# (5192, 7)

# %%
NUM_CLASSES = len(input_embedding_d_2['predict_labels'].unique()) + 2   #base_df['paper_id'].max()+2
NUM_CLASSES  #11840
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b950c21770f8> in <cell line: 1>()
# ----> 1 NUM_CLASSES = len(input_embedding_d_2['predict_labels'].unique()) + 2   #base_df['paper_id'].max()+2
#       2 NUM_CLASSES  #11840
#
# NameError: name 'input_embedding_d_2' is not defined

# %%
#들어온 embedding값을 평균내는 클래스
class MaskedEmbeddingsAggregatorLayer(keras.layers.Layer):
  def __init__(self, agg_mode = 'mean', **kwargs):
    super(MaskedEmbeddingsAggregatorLayer, self).__init__(**kwargs)
    self.agg_mode = agg_mode

  @tf.function
  def call(self, inputs, mask = None):  #feedforward
    masked_embeddings = tf.ragged.boolean_mask(inputs, mask)  #입력 임베딩 masking
    #print("masked_embeddings:", masked_embeddings)
    aggregated = tf.reduce_mean(inputs, axis = 1)  #평균
    print("aggregated:", aggregated)
    return aggregated

  def get_config(self):
    return {'agg_mode' : self.agg_mode}


#L2NormLayer적용하는 클래스
class L2NormLayer(keras.layers.Layer):
  def __init__(self, **kwargs):
    super(L2NormLayer, self).__init__(**kwargs)

  @tf.function
  def call(self, inputs, mask = None):
    if mask is None:  #mask가 none이 아니면 mask 적용
      inputs = tf.ragged.boolean_mask(inputs, mask).to_tensor()

    return tf.math.l2_normalize(inputs, axis = -1)

  def compute_mask(self, inputs, mask):  #mask반환하기 위해서
    #print(mask)
    return mask




class CandidateGeneration(keras.Model):
  def __init__(self, inputs, embedding_dims):  #input과 embedding 차원을 받음
    super(CandidateGeneration, self).__init__()

    self.inputs = inputs
    self.embedding_dims = embedding_dims

    #input받은걸 4개로 나눔
    self.input_watch_hist, self.input_watch_hist_time, self.input_search_hist, self.input_example_age, self.input_features = self.inputs

    #embedding layer, aggregation layer 설정
    self.feature_embeddings = keras.layers.Embedding(input_dim = NUM_CLASSES, output_dim = embedding_dims, mask_zero = True, trainable = True)
    self.avg_embeddings = MaskedEmbeddingsAggregatorLayer(agg_mode = 'mean')

    #dense layer설정
    self.dense_layer_list = [keras.layers.Dense(units = i) for i in config.layers]
    self.dense_output = keras.layers.Dense(NUM_CLASSES, activation = 'softmax')

    #배치정규화
    self.batch_norm_layers = [keras.layers.BatchNormalization() for _ in range(3)]
    self.drop_out_layers = [keras.layers.Dropout(0.5) for _ in range(3)]

  def call(self, inputs):
    input_watch_hist, input_watch_hist_time, input_search_hist, input_example_age, input_features = inputs
    print("input_shape:", input_watch_hist)

    avg_watches = self.embeddings(input_watch_hist)
    avg_watch_hist = self.embeddings(input_watch_hist_time)
    avg_searches = self.embeddings(input_search_hist)      #shape=(5340, 16)
    avg_example_age = self.embeddings(input_example_age)   #shape=(5340, 16)
    avg_features = self.embeddings(input_features)
    print("avg_features:", avg_watches)


    #임베딩 합치기
    concat_inputs = keras.layers.Concatenate(axis = 1)([avg_watches, avg_watch_hist, avg_searches, avg_example_age, avg_features])
    print("concat_inputs:", concat_inputs.shape)
    results = concat_inputs   #shape=(5340, 64)

    #dense layer, batch normalization layer-> neural network통과
    for dense_layer, batch_norm_layer in zip(self.dense_layer_list, self.batch_norm_layers):
      dense_features = dense_layer(results)
      print("dense_features:", dense_features)
      dense_relu = keras.layers.ReLU()(dense_features)
      dense_batch_norm = batch_norm_layer(dense_relu)
      results = dense_batch_norm
      print("results:",results)

    outputs = self.dense_output(results)
    print("outputs:", outputs)
    return outputs

  def embeddings(self, input_feature):
    #print("input_feature_in_emb:", input_feature)
    embeddings = self.feature_embeddings(input_feature)
    print("embedding_out:", embeddings)
    l2_norm_features = L2NormLayer()(embeddings)
    avgg_features = self.avg_embeddings(l2_norm_features)

    print("avgg_features:", avgg_features)

    return avgg_features

# %%
config = {
    'epochs': 100,
    'top_k':10,
    'lr' : 0.01,
    'embedding_dims' : 16,
    'dense_units' : 64,
    'layers': [1024, 512, 256]
}

config = Box(config)

#input선언 및 초기화
input_watch_hist = keras.layers.Input(shape = (None,))
input_watch_hist_time = keras.layers.Input(shape = (None,))
input_search_hist = keras.layers.Input(shape = (None,))
input_example_age = keras.layers.Input(shape = (None,))
input_features = keras.layers.Input(shape = (None,))

#초기화 해서 input list에 넣어줌
inputs = [input_watch_hist, input_watch_hist_time, input_search_hist, input_example_age, input_features]

model = CandidateGeneration(inputs, config.embedding_dims)
model.compile(optimizer = keras.optimizers.Adam(learning_rate = config.lr),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['acc'])

batch_size = 32

history = model.fit([sequence.pad_sequences(train_data['write_hist']),
                     sequence.pad_sequences(train_data['paper_age'], dtype = float),
                     sequence.pad_sequences(train_data['source']),
                     sequence.pad_sequences(train_data['citation'], dtype = float),
                     sequence.pad_sequences(train_data['features'], padding = 'post'),],
                    train_data['predict_labels'].values,
                    steps_per_epoch = 100, epochs = config.epochs, )#batch_size = batch_si
# Out:
# Epoch 1/100
# input_shape: Tensor("IteratorGetNext:0", shape=(None, 54), dtype=int32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_1/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_1:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_2/Identity_1:0", shape=(None, 55, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_2:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_3/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_3:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_4/Identity_1:0", shape=(None, 1484, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall:0", shape=(None, 16), dtype=float32)
# concat_inputs: (None, 80)
# dense_features: Tensor("candidate_generation_32/dense_127/BiasAdd:0", shape=(None, 1024), dtype=float32)
# results: Tensor("candidate_generation_32/batch_normalization_96/batchnorm/add_1:0", shape=(None, 1024), dtype=float32)
# dense_features: Tensor("candidate_generation_32/dense_128/BiasAdd:0", shape=(None, 512), dtype=float32)
# results: Tensor("candidate_generation_32/batch_normalization_97/batchnorm/add_1:0", shape=(None, 512), dtype=float32)
# dense_features: Tensor("candidate_generation_32/dense_129/BiasAdd:0", shape=(None, 256), dtype=float32)
# results: Tensor("candidate_generation_32/batch_normalization_98/batchnorm/add_1:0", shape=(None, 256), dtype=float32)
# outputs: Tensor("candidate_generation_32/dense_130/Softmax:0", shape=(None, 11840), dtype=float32)
# input_shape: Tensor("IteratorGetNext:0", shape=(None, 54), dtype=int32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_1/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_1:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_2/Identity_1:0", shape=(None, 55, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_2:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_3/Identity_1:0", shape=(None, 54, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_3:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_32/embedding_32/embedding_lookup_4/Identity_1:0", shape=(None, 1484, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_32/masked_embeddings_aggregator_layer_32/PartitionedCall:0", shape=(None, 16), dtype=float32)
# concat_inputs: (None, 80)
# dense_features: Tensor("candidate_generation_32/dense_127/BiasAdd:0", shape=(None, 1024), dtype=float32)
# results: Tensor("candidate_generation_32/batch_normalization_96/batchnorm/add_1:0", shape=(None, 1024), dtype=float32)
# dense_features: Tensor("candidate_generation_32/dense_128/BiasAdd:0", shape=(None, 512), dtype=float32)
# results: Tensor("candidate_generation_32/batch_normalization_97/batchnorm/add_1:0", shape=(None, 512), dtype=float32)
# dense_features: Tensor("candidate_generation_32/dense_129/BiasAdd:0", shape=(None, 256), dtype=float32)
# results: Tensor("candidate_generation_32/batch_normalization_98/batchnorm/add_1:0", shape=(None, 256), dtype=float32)
# outputs: Tensor("candidate_generation_32/dense_130/Softmax:0", shape=(None, 11840), dtype=float32)
#  61/100 [=================>............] - ETA: 5s - loss: nan - acc: 0.0000e+00

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize = (10, 4))

ax[0].plot(history.history['acc'])
ax[0].set_title('Train Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')

ax[1].plot(history.history['loss'])
ax[1].set_title('Train Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')

fig.tight_layout()
plt.show()

# %%
# 테스트 데이터 준비 (예시)
#test_inputs = [test_data['write_hist'], test_data['paper_age'], test_data['source'], test_data['citation']]
#test_labels = test_data['predict_labels'].values

# 모델 평가
loss, accuracy = model.evaluate([sequence.pad_sequences(test_data['write_hist']),
                                 sequence.pad_sequences(test_data['paper_age'], dtype = float),
                                 sequence.pad_sequences(test_data['source']),
                                 sequence.pad_sequences(test_data['citation'], dtype = float),
                                 sequence.pad_sequences(test_data['features'])],
                                 test_data['predict_labels'].values, )

print(" Loss:",loss,"\n","Accuracy:", accuracy)
# Out:
# input_shape: Tensor("IteratorGetNext:0", shape=(None, 30), dtype=int32)
# embedding_out: Tensor("candidate_generation_24/embedding_24/embedding_lookup/Identity_1:0", shape=(None, 30, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_24/masked_embeddings_aggregator_layer_24/PartitionedCall:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_24/embedding_24/embedding_lookup_1/Identity_1:0", shape=(None, 30, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_24/masked_embeddings_aggregator_layer_24/PartitionedCall_1:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_24/embedding_24/embedding_lookup_2/Identity_1:0", shape=(None, 31, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_24/masked_embeddings_aggregator_layer_24/PartitionedCall_2:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_24/embedding_24/embedding_lookup_3/Identity_1:0", shape=(None, 30, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_24/masked_embeddings_aggregator_layer_24/PartitionedCall_3:0", shape=(None, 16), dtype=float32)
# embedding_out: Tensor("candidate_generation_24/embedding_24/embedding_lookup_4/Identity_1:0", shape=(None, 1077, 16), dtype=float32)
# aggregated: Tensor("Mean:0", shape=(None, 16), dtype=float32)
# avgg_features: Tensor("candidate_generation_24/masked_embeddings_aggregator_layer_24/PartitionedCall_4:0", shape=(None, 16), dtype=float32)
# avg_features: Tensor("candidate_generation_24/masked_embeddings_aggregator_layer_24/PartitionedCall:0", shape=(None, 16), dtype=float32)
# concat_inputs: (None, 80)
# dense_features: Tensor("candidate_generation_24/dense_99/BiasAdd:0", shape=(None, 256), dtype=float32)
# results: Tensor("candidate_generation_24/batch_normalization_72/batchnorm/add_1:0", shape=(None, 256), dtype=float32)
# dense_features: Tensor("candidate_generation_24/dense_100/BiasAdd:0", shape=(None, 128), dtype=float32)
# results: Tensor("candidate_generation_24/batch_normalization_73/batchnorm/add_1:0", shape=(None, 128), dtype=float32)
# outputs: Tensor("candidate_generation_24/dense_101/Softmax:0", shape=(None, 15434), dtype=float32)
# 163/163 [==============================] - 1s 4ms/step - loss: 102.6564 - acc: 0.0081
#  Loss: 102.6563949584961
#  Accuracy: 0.008089368231594563

# %%
sequence.pad_sequences()
